# %%
import re
import numpy as np 
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (30,20)
plt.style.use('ggplot')

# %%
df = pd.read_csv("Combined Data.csv", index_col=[0])

# %%
df
# Out:
#              Brand                                       Product Name  \
# 0            APPLE  AirPods Max - Noise Cancelling Over-Ear Headph...
# 1             Bose                                       Sleepbuds II
# 2          Samsung                  SAMSUNG Original Headphones EG920
# 3     Turtle Beach  Stealth 700 Gen 2 Wireless Headset - Xbox Seri...
# 4             AWEI  A780BL Bluetooth Headphones Foldable Noise Can...
# ...            ...                                                ...
# 3463       Samsung   Galaxy Z Flip3 5G (8GB+256GB) Phantom Black S...
# 3464       Samsung   Galaxy Z Flip3 5G (8GB+256GB) Green Smartphon...
# 3465       Samsung   Galaxy Z Flip3 5G (8GB+256GB) Lavender Purple...
# 3466       Samsung   Galaxy Z Flip3 5G (8GB+256GB) Cream White Sma...
# 3467        Xiaomi  Redmi Note10 5G 128GB Gray Smartphone【CMHK rec...
#
#       Sales Volume Product Category  Rating  Number of Review  Price
# ...

# %% [markdown]
# from mpl_toolkits.mplot3d import Axes3D
# #%matplotlib widget
#
# sns.set(style = "darkgrid")
#
# fig = plt.figure()
# ax = fig.add_subplot(111, projection = '3d')
#
# x = df['Rating']
# y = df['Sales Volume']
# z = df['Number of Review']
#
# ax.set_xlabel("Rating")
# ax.set_ylabel("Sales Volume")
# ax.set_zlabel("Number of Review")
#
# ax.scatter(x, y, z)
#
# plt.show()

# %%
revenue = df["Sales Volume"] * df["Price"]
revenue
# Out:
# 0       36990
# 1       19990
# 2       35600
# 3       21980
# 4       37600
#         ...
# 3463        0
# 3464        0
# 3465        0
# 3466        0
# 3467        0
# Length: 3468, dtype: int64

# %%
temp = pd.concat([df["Brand"],revenue],axis=1)

# %%
temp.rename(columns={0: "Revenue"},inplace=True)

# %%
temp.groupby("Brand")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Brand
# Samsung          8010500
# APPLE            4526290
# AMAZON           3396720
# Fitbit            909010
# Xiaomi            825780
#                   ...
# Lamborghini            0
# Little Genius          0
# MAD Gaze               0
# MARVEL                 0
# MOFT                   0
# Name: Revenue, Length: 338, dtype: int64

# %%
temp.groupby("Brand")["Revenue"].sum().sort_values(ascending=False).plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Revenue'>

# %%
test = {"a":1,"b":2,"c":3}

# %%
new
# Out:
# a
# b
# c

# %%
sns.set(font_scale=3)
sns.scatterplot(data=df, x="Rating", y="Sales Volume", hue="Product Category", alpha=0.7, size="Number of Review",sizes=(100,2500))
plt.savefig("scatter1.png")

# %%
sns.set(font_scale=3)
sns.scatterplot(data=df, x="Number of Review", y="Sales Volume", hue="Product Category", s=500, alpha=0.7)
# Out:
# <AxesSubplot:xlabel='Number of Review', ylabel='Sales Volume'>
